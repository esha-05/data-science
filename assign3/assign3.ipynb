# %%
import pandas as pd

df = pd.read_csv("owid-covid-data.csv")

df.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-01-05          0.0        0.0
# 1      AFG      Asia  Afghanistan  2020-01-06          0.0        0.0
# 2      AFG      Asia  Afghanistan  2020-01-07          0.0        0.0
# 3      AFG      Asia  Afghanistan  2020-01-08          0.0        0.0
# 4      AFG      Asia  Afghanistan  2020-01-09          0.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           0.0         0.0                  NaN  ...
# 1                 NaN           0.0         0.0                  NaN  ...
# 2                 NaN           0.0         0.0                  NaN  ...
# 3                 NaN           0.0         0.0                  NaN  ...
# 4                 NaN           0.0         0.0                  NaN  ...
#
#    male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# ...

# %%
df = df[['location', 'date', 'total_cases', 'new_cases', 'total_deaths', 'new_deaths']]

df.head()
# Out:
#       location        date  total_cases  new_cases  total_deaths  new_deaths
# 0  Afghanistan  2020-01-05          0.0        0.0           0.0         0.0
# 1  Afghanistan  2020-01-06          0.0        0.0           0.0         0.0
# 2  Afghanistan  2020-01-07          0.0        0.0           0.0         0.0
# 3  Afghanistan  2020-01-08          0.0        0.0           0.0         0.0
# 4  Afghanistan  2020-01-09          0.0        0.0           0.0         0.0

# %%
# Convert date
df['date'] = pd.to_datetime(df['date'])

# missing values
df.fillna(0, inplace=True)

# filter one country
india_df = df[df['location'] == 'India']

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.plot(india_df['date'], india_df['total_cases'])

plt.title("COVID-19 Total Cases in India")
plt.xlabel("Date")
plt.ylabel("Total Cases")
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.plot(india_df['date'], india_df['new_cases'])

plt.title("Daily New Cases in India")
plt.xlabel("Date")
plt.ylabel("New Cases")
plt.show()

# %%
import seaborn as sns

numeric_df = india_df.select_dtypes(include='number')

plt.figure(figsize=(8,5))
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %%
sns.boxplot(x=india_df['new_cases'])
plt.title("Outliers in Daily Cases")
plt.show()

# %% [markdown]
# # 📊 Key Insights
#
# ### 1. Trend Insight
# The total cases show a sharp increase during peak pandemic periods, indicating waves of infection.
#
# ### 2. Correlation Insight
# New cases and total cases are strongly correlated, showing that daily increases directly contribute to overall spread.
#
# ### 3. Outlier Insight
# Outliers in new cases indicate sudden spikes, possibly due to reporting delays or outbreak clusters.
